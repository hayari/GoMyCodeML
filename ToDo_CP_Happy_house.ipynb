# %% [markdown]
# <a href="https://colab.research.google.com/github/hayari/GoMyCodeML/blob/master/ToDo_CP_Happy_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

np.random.seed(100)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %%
text_labels={
    0: "not happy",
    1: "happy"
}

def plot_prediction_sample(model):
  test_predictions=model.predict_classes(X_test)
  plt.figure(figsize=(10,10))
  for i in range(25):
      plt.subplot(5,5,i+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid('off')
      
      img_index = np.random.randint(0, 150)
      
      plt.imshow(X_test[img_index], cmap=plt.cm.gray)
      
      actual_label = int(Y_test[img_index])
      predicted_label = int(test_predictions[img_index])
      
      plt.xlabel("image {} \n Actual: {} ({})\n Predicted: {} ({})".format(
          img_index,actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
      ))
      
  plt.tight_layout()
  plt.show()

optimizer_results={}

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential([
                    Conv2D(filters=32,padding='same',kernel_size=(3,3), activation='relu',input_shape=(64, 64, 3)),
                    BatchNormalization(),
                    MaxPooling2D(),
                    Flatten(),
                    Dense(1, activation='sigmoid')
                    ])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 33,793
# Trainable params: 33,729
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# **ADAM optimizer**

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
from keras.callbacks import EarlyStopping
stopcallback = EarlyStopping(monitor='loss', patience=10,min_delta=0.001)
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 3s 5ms/step - loss: 1.3308 - accuracy: 0.6520 - val_loss: 0.5644 - val_accuracy: 0.7100
# Epoch 2/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.3326 - accuracy: 0.8600 - val_loss: 0.4940 - val_accuracy: 0.9000
# Epoch 3/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1732 - accuracy: 0.9280 - val_loss: 0.5016 - val_accuracy: 0.7700
# Epoch 4/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1029 - accuracy: 0.9720 - val_loss: 0.4805 - val_accuracy: 0.8300
# Epoch 5/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0787 - accuracy: 0.9760 - val_loss: 0.4292 - val_accuracy: 0.9500
# Epoch 6/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0455 - accuracy: 0.9880 - val_loss: 0.4252 - val_accuracy: 0.9700
# Epoch 7/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0365 - accuracy: 0.9920 - val_loss: 0.4000 - val_accuracy: 0.9800
# Epoch 8/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0363 - accuracy: 0.9960 - val_loss: 0.4101 - val_accuracy: 0.9300
# Epoch 9/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0349 - accuracy: 0.9920 - val_loss: 0.3598 - val_accuracy: 0.9700
# Epoch 10/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0243 - accuracy: 0.9960 - val_loss: 0.3446 - val_accuracy: 0.9700
# Epoch 11/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0191 - accuracy: 0.9960 - val_loss: 0.3305 - val_accuracy: 1.0000
# Epoch 12/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9860 - val_loss: 0.3182 - val_accuracy: 0.9900
# Epoch 13/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 0.4367 - val_accuracy: 0.7000
# Epoch 14/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0436 - accuracy: 0.9900 - val_loss: 0.2469 - val_accuracy: 0.9900
# Epoch 15/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.2546 - val_accuracy: 0.9400
# Epoch 16/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0223 - accuracy: 0.9940 - val_loss: 0.2547 - val_accuracy: 0.9400
# Epoch 17/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0219 - accuracy: 0.9900 - val_loss: 0.2340 - val_accuracy: 1.0000
# Epoch 18/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9900
# Epoch 19/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.1998 - val_accuracy: 1.0000
# Epoch 20/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 0.1560 - val_accuracy: 0.9800
# Epoch 21/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.1521 - val_accuracy: 1.0000
# Epoch 22/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.1645 - val_accuracy: 0.9700
# Epoch 23/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9900
# Epoch 24/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.1142 - val_accuracy: 0.9800
# Epoch 25/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.1581 - val_accuracy: 0.9500
# Epoch 26/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0202 - accuracy: 0.9920 - val_loss: 0.0993 - val_accuracy: 0.9800
# Epoch 27/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0098 - accuracy: 0.9980 - val_loss: 0.2170 - val_accuracy: 0.9200
# Epoch 28/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0760 - val_accuracy: 0.9900
# Epoch 29/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0681 - val_accuracy: 0.9800

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Evaluate Test set

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAM"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.13149650851885478, 0.95333331823349]

# %% [markdown]
# Confusion Matrix

# %%
confusion_matrix(Y_test.reshape(-1),model.predict_classes(X_test))
# Out:
# array([[66,  0],
#        [ 7, 77]])

# %%
plot_prediction_sample(model)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %% [markdown]
# **RMSPROP optimizer**

# %%
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.9843 - accuracy: 0.8960 - val_loss: 0.2238 - val_accuracy: 0.9000
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.0441 - val_accuracy: 0.9900
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.3194 - accuracy: 0.9300 - val_loss: 0.3310 - val_accuracy: 0.8700
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1147 - val_accuracy: 0.9500
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.4195 - val_accuracy: 0.8600
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0675 - accuracy: 0.9780 - val_loss: 0.0822 - val_accuracy: 0.9600
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0248 - accuracy: 0.9880 - val_loss: 0.0578 - val_accuracy: 0.9900
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1714 - accuracy: 0.9540 - val_loss: 0.1837 - val_accuracy: 0.9100
# Epoch 9/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0164 - accuracy: 0.9960 - val_loss: 0.0882 - val_accuracy: 0.9700
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0166 - accuracy: 0.9940 - val_loss: 0.0769 - val_accuracy: 0.9700
# Epoch 11/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0928 - accuracy: 0.9780 - val_loss: 0.1170 - val_accuracy: 0.9600
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0686 - val_accuracy: 0.9800
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1656 - accuracy: 0.9680 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 14/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0064 - accuracy: 0.9960 - val_loss: 1.1214 - val_accuracy: 0.7600
# Epoch 15/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0303 - accuracy: 0.9920 - val_loss: 0.0421 - val_accuracy: 0.9900
# Epoch 16/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9700
# Epoch 17/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0727 - accuracy: 0.9860 - val_loss: 0.0330 - val_accuracy: 0.9900
# Epoch 18/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1034 - accuracy: 0.9780 - val_loss: 0.1064 - val_accuracy: 0.9700
# Epoch 19/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0936 - val_accuracy: 0.9600
# Epoch 20/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0474 - accuracy: 0.9900 - val_loss: 0.0684 - val_accuracy: 0.9800
# Epoch 21/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2489 - val_accuracy: 0.9000
# Epoch 22/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1081 - accuracy: 0.9700 - val_loss: 0.0524 - val_accuracy: 0.9800
# Epoch 23/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0119 - accuracy: 0.9980 - val_loss: 0.1476 - val_accuracy: 0.9600
# Epoch 24/100
# 500/500 [==============================] - 2s 4ms/step - loss: 2.9472e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9600
# Epoch 25/100
# 500/500 [==============================] - 2s 4ms/step - loss: 6.7095e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 26/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1532 - accuracy: 0.9660 - val_loss: 0.0802 - val_accuracy: 0.9700
# Epoch 27/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0254 - accuracy: 0.9940 - val_loss: 0.0591 - val_accuracy: 0.9800
# Epoch 28/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9900
# Epoch 29/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.7612e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9800
# Epoch 30/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1019 - accuracy: 0.9740 - val_loss: 0.0201 - val_accuracy: 0.9900
# Epoch 31/100
# 500/500 [==============================] - 2s 4ms/step - loss: 2.8947e-04 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9900
# Epoch 32/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 2.2893 - val_accuracy: 0.7200
# Epoch 33/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0589 - accuracy: 0.9900 - val_loss: 0.2318 - val_accuracy: 0.9600
# Epoch 34/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.1022 - val_accuracy: 0.9600

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["RMSPROP"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.2789916960398356, 0.9266666769981384]

# %%
plot_prediction_sample(model)

# %% [markdown]
# **ADAgrad optimizer**

# %%
model.compile(optimizer='adagrad', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 4.8468 - accuracy: 0.8360 - val_loss: 13.7931 - val_accuracy: 0.5300
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0142 - accuracy: 0.9940 - val_loss: 8.6194 - val_accuracy: 0.5300
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 0.9980 - val_loss: 6.2467 - val_accuracy: 0.5500
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 4.0428 - val_accuracy: 0.6200
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.8233 - val_accuracy: 0.6300
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0097 - accuracy: 0.9960 - val_loss: 3.2351 - val_accuracy: 0.6600
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2844 - val_accuracy: 0.7700
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7755 - val_accuracy: 0.8200
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5045 - val_accuracy: 0.8700
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9500
# Epoch 11/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2999 - val_accuracy: 0.9000
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4578 - val_accuracy: 0.8800
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9900
# Epoch 14/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9900
# Epoch 15/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9900
# Epoch 16/100
# 500/500 [==============================] - 2s 4ms/step - loss: 8.8008e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9900
# Epoch 17/100
# 500/500 [==============================] - 2s 4ms/step - loss: 9.3032e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9900
# Epoch 18/100
# 500/500 [==============================] - 2s 4ms/step - loss: 8.8586e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 19/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 20/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 21/100
# 500/500 [==============================] - 2s 4ms/step - loss: 9.7355e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 22/100
# 500/500 [==============================] - 2s 4ms/step - loss: 9.1805e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 23/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 24/100
# 500/500 [==============================] - 2s 4ms/step - loss: 8.9727e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 25/100
# 500/500 [==============================] - 2s 4ms/step - loss: 7.9984e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 26/100
# 500/500 [==============================] - 2s 4ms/step - loss: 9.0259e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAGRADE"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.14159633837640284, 0.9599999785423279]

# %%
plot_prediction_sample(model)

# %% [markdown]
# **ADAmax optimizer**

# %%
model.compile(optimizer='Adamax', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0733 - accuracy: 0.9780 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0097 - accuracy: 0.9960 - val_loss: 0.0540 - val_accuracy: 0.9800
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 8.3113e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 6.4012e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 5.5702e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.2739e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.9919e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.9270e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.7155e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 11/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.7161e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.4742e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.8418e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 14/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.5046e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 15/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.6796e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 16/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.6817e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 17/100
# 500/500 [==============================] - 2s 4ms/step - loss: 4.5685e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 18/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.3375e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 19/100
# 500/500 [==============================] - 2s 4ms/step - loss: 3.1279e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAMAX"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.11943688612741729, 0.9599999785423279]

# %%
plot_prediction_sample(model)

# %% [markdown]
# ## Compare optimizers

# %%
import pandas as pd
pd.DataFrame(optimizer_results,index=["Loss","Accuracy"])
# Out:
#               ADAM   RMSPROP  ADAGRADE    ADAMAX
# Loss      0.131497  0.278992  0.141596  0.119437
# Accuracy  0.953333  0.926667  0.960000  0.960000
