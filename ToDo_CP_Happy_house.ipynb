# %% [markdown]
# <a href="https://colab.research.google.com/github/hayari/GoMyCodeML/blob/master/ToDo_CP_Happy_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %%
text_labels={
    0: "not happy",
    1: "happy"
}

def plot_prediction_sample(model):
  test_predictions=model.predict_classes(X_test)
  plt.figure(figsize=(10,10))
  for i in range(25):
      plt.subplot(5,5,i+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid('off')
      
      img_index = np.random.randint(0, 150)
      
      plt.imshow(X_test[img_index], cmap=plt.cm.gray)
      
      actual_label = int(Y_test[img_index])
      predicted_label = int(test_predictions[img_index])
      
      plt.xlabel("image {} \n Actual: {} ({})\n Predicted: {} ({})".format(
          img_index,actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
      ))
      
  plt.tight_layout()
  plt.show()

optimizer_results={}

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential([
                    Conv2D(filters=32,padding='same',kernel_size=(3,3), activation='relu',input_shape=(64, 64, 3)),
                   BatchNormalization(),
                    MaxPooling2D(),
                    Flatten(),
                    Dense(1, activation='sigmoid')
                    ])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 33,793
# Trainable params: 33,729
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# **ADAM optimizer**

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
from keras.callbacks import EarlyStopping
stopcallback = EarlyStopping(monitor='loss', patience=3,min_delta=0.001)
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.6856 - accuracy: 0.6960 - val_loss: 0.5984 - val_accuracy: 0.7300
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1725 - accuracy: 0.9400 - val_loss: 0.5582 - val_accuracy: 0.9200
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1007 - accuracy: 0.9640 - val_loss: 0.5289 - val_accuracy: 0.9100
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0710 - accuracy: 0.9800 - val_loss: 0.5094 - val_accuracy: 0.9600
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0466 - accuracy: 0.9880 - val_loss: 0.5040 - val_accuracy: 0.9500
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0401 - accuracy: 0.9920 - val_loss: 0.4820 - val_accuracy: 0.9800
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0318 - accuracy: 0.9920 - val_loss: 0.4494 - val_accuracy: 0.9400
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0274 - accuracy: 0.9940 - val_loss: 0.4379 - val_accuracy: 0.9800
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0255 - accuracy: 0.9940 - val_loss: 0.4144 - val_accuracy: 0.9700
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0264 - accuracy: 0.9940 - val_loss: 0.4019 - val_accuracy: 0.9800
# Epoch 11/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0221 - accuracy: 0.9960 - val_loss: 0.3788 - val_accuracy: 0.9800
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.3468 - val_accuracy: 0.9700
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0122 - accuracy: 0.9980 - val_loss: 0.3351 - val_accuracy: 0.9800
# Epoch 14/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.3171 - val_accuracy: 0.9800
# Epoch 15/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0156 - accuracy: 0.9920 - val_loss: 0.3056 - val_accuracy: 0.9800
# Epoch 16/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0215 - accuracy: 0.9920 - val_loss: 0.3126 - val_accuracy: 0.9000

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Evaluate Test set

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAM"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.31339171012242634, 0.8933333158493042]

# %% [markdown]
# Confusion Matrix

# %%
confusion_matrix(Y_test.reshape(-1),model.predict_classes(X_test))
# Out:
# array([[51, 15],
#        [ 1, 83]])

# %%
plot_prediction_sample(model)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %% [markdown]
# **RMSPROP optimizer**

# %%
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.3844 - accuracy: 0.9440 - val_loss: 0.2634 - val_accuracy: 0.9700
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1205 - accuracy: 0.9620 - val_loss: 0.3324 - val_accuracy: 0.8500
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0605 - accuracy: 0.9800 - val_loss: 0.1915 - val_accuracy: 0.9800
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1353 - accuracy: 0.9600 - val_loss: 0.6399 - val_accuracy: 0.5700
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0563 - accuracy: 0.9740 - val_loss: 0.1506 - val_accuracy: 0.9600
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 0.1332 - val_accuracy: 0.9900
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1462 - accuracy: 0.9540 - val_loss: 0.1245 - val_accuracy: 0.9900
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.1126 - val_accuracy: 0.9700
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1017 - accuracy: 0.9660 - val_loss: 0.1460 - val_accuracy: 0.9600

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["RMSPROP"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.17097460250059762, 0.95333331823349]

# %%
plot_prediction_sample(model)

# %% [markdown]
# **ADAgrad optimizer**

# %%
model.compile(optimizer='adagrad', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 5.5249 - accuracy: 0.6900 - val_loss: 5.6333 - val_accuracy: 0.4700
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.2378 - accuracy: 0.9300 - val_loss: 4.2757 - val_accuracy: 0.4700
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0544 - accuracy: 0.9820 - val_loss: 3.3994 - val_accuracy: 0.4700
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0573 - accuracy: 0.9780 - val_loss: 1.6541 - val_accuracy: 0.5300
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.9940 - val_loss: 2.6400 - val_accuracy: 0.4700
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0286 - accuracy: 0.9940 - val_loss: 2.3619 - val_accuracy: 0.4800
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0214 - accuracy: 0.9960 - val_loss: 1.1202 - val_accuracy: 0.5800
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0266 - accuracy: 0.9980 - val_loss: 1.0641 - val_accuracy: 0.6300
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0182 - accuracy: 0.9980 - val_loss: 0.5872 - val_accuracy: 0.7300
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0213 - accuracy: 0.9960 - val_loss: 0.7668 - val_accuracy: 0.7300
# Epoch 11/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 0.2758 - val_accuracy: 0.8400
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0151 - accuracy: 0.9980 - val_loss: 0.2666 - val_accuracy: 0.8500
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 0.1182 - val_accuracy: 0.9400
# Epoch 14/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0111 - accuracy: 0.9980 - val_loss: 0.0825 - val_accuracy: 0.9700

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAGRADE"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.12141401569048564, 0.95333331823349]

# %%
plot_prediction_sample(model)

# %% [markdown]
# **ADAmax optimizer**

# %%
model.compile(optimizer='Adamax', loss='binary_crossentropy', metrics=["accuracy"])
history_model = model.fit(X_train[:500,:,:,:],Y_train[:500,:],epochs=100, batch_size=32, validation_data=(X_train[500:,:,:,:],Y_train[500:,:]),callbacks=[stopcallback])
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0894 - accuracy: 0.9620 - val_loss: 0.2706 - val_accuracy: 0.8800
# Epoch 2/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.0876 - val_accuracy: 0.9700
# Epoch 3/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.0634 - val_accuracy: 0.9800
# Epoch 4/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0108 - accuracy: 0.9980 - val_loss: 0.0659 - val_accuracy: 0.9800
# Epoch 5/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.0608 - val_accuracy: 0.9800
# Epoch 6/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0111 - accuracy: 0.9980 - val_loss: 0.0361 - val_accuracy: 0.9800
# Epoch 7/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0499 - val_accuracy: 0.9800
# Epoch 8/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.0500 - val_accuracy: 0.9800
# Epoch 9/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0411 - val_accuracy: 0.9900
# Epoch 10/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0420 - val_accuracy: 0.9900
# Epoch 11/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0386 - val_accuracy: 0.9900
# Epoch 12/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9800
# Epoch 13/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.0441 - val_accuracy: 0.9900
# Epoch 14/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 0.0353 - val_accuracy: 0.9900
# Epoch 15/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0481 - val_accuracy: 0.9700

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
plt.plot(history_model.history['accuracy'])
plt.plot(history_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Test Evaluation**

# %%
result= model.evaluate(
  X_test,
  Y_test.reshape(-1))
optimizer_results["ADAMAX"]=result  
print(result)
# Out:
# 150/150 [==============================] - 0s 2ms/step
# [0.08494196852048239, 0.9800000190734863]

# %%
plot_prediction_sample(model)

# %% [markdown]
# ## Compare optimizers

# %%
import pandas as pd
pd.DataFrame(optimizer_results,index=["Loss","Accuracy"])
# Out:
#               ADAM   RMSPROP  ADAGRADE    ADAMAX
# Loss      0.313392  0.170975  0.121414  0.084942
# Accuracy  0.893333  0.953333  0.953333  0.980000
